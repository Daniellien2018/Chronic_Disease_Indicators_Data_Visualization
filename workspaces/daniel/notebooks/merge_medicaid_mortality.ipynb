# %%
import pandas as pd

# %%
medicaid_path = '/home/daniel.lien/dev/homework/data/medicaid_data_cleaned.csv'
mortality_path = '/home/daniel.lien/dev/homework/data/cleaned_copd_data_final.csv'

# %%
medicaid_df = pd.read_csv(medicaid_path)
mortality_df = pd.read_csv(mortality_path)

# %%
df_merged = pd.merge(mortality_df, medicaid_df[['State', 'Year', 'Medicaid_Spending']],
                    on=['State', 'Year'], how='left')

# %%
#Drop Question 
df_merged = df_merged.drop(columns='Question')

# %%
output_dir = '/home/daniel.lien/dev/homework/data/merged_medicaid_mortality.csv'
df_merged.to_csv(output_dir, index=False)

# %% [markdown]
# DONE
