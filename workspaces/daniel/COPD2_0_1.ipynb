# %% [markdown]
# # This is Prevalence of COPD in adults >= 45
# COPD2_0_1: Prevalence of chronic obstructive pulmonary disease among adults >= 45 years

# %%
import pandas as pd
csv_path = '/home/daniel.lien/dev/homework/data/cleaned_copd_data.csv'
df = pd.read_csv(csv_path)
df.head()
# Out:
#    YearStart LocationDesc                                  Topic  \
# 0       2014       Alaska  Chronic Obstructive Pulmonary Disease
# 1       2020      Alabama  Chronic Obstructive Pulmonary Disease
# 2       2012      Alabama  Chronic Obstructive Pulmonary Disease
# 3       2015      Alabama  Chronic Obstructive Pulmonary Disease
# 4       2017      Alabama  Chronic Obstructive Pulmonary Disease
#
#                                             Question DataValueUnit  \
# 0  Mortality with chronic obstructive pulmonary d...        Number
# 1  Mortality with chronic obstructive pulmonary d...        Number
# 2  Mortality with chronic obstructive pulmonary d...        Number
# 3  Mortality with chronic obstructive pulmonary d...        Number
# 4  Mortality with chronic obstructive pulmonary d...        Number
#
#   DataValueType  DataValue StratificationCategory1      Stratification1  \
# 0        Number       89.0                  Gender                 Male
# ...

# %%
df.shape
# Out:
# (143586, 13)

# %%
# Filter for only COPD1_1 12497 / 143586 
df = df[df['QuestionID'] == 'COPD2_0_1']
df.shape
# Out:
# (8800, 13)

# %%
# save to csv
output_dir = '/home/daniel.lien/dev/homework/data/Single_Questions/COPD2_0_1.csv'
df.to_csv(output_dir, index=False)
