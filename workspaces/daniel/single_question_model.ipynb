# %%
import pandas as pd
csv_path = '/home/daniel.lien/dev/homework/data/cleaned_copd_data_question_COPD01.csv'
df = pd.read_csv(csv_path)
df.head()
# Out:
#    YearStart  YearEnd LocationDesc DataSource  \
# 0       2019     2019     Arkansas      BRFSS
# 1       2019     2019   California      BRFSS
# 2       2019     2019      Alabama      BRFSS
# 3       2019     2019   California      BRFSS
# 4       2019     2019      Arizona      BRFSS
#
#                                    Topic  \
# 0  Chronic Obstructive Pulmonary Disease
# 1  Chronic Obstructive Pulmonary Disease
# 2  Chronic Obstructive Pulmonary Disease
# 3  Chronic Obstructive Pulmonary Disease
# 4  Chronic Obstructive Pulmonary Disease
#
#                                             Question DataValueUnit  \
# 0  Chronic obstructive pulmonary disease among ad...             %
# 1  Chronic obstructive pulmonary disease among ad...             %
# 2  Chronic obstructive pulmonary disease among ad...             %
# 3  Chronic obstructive pulmonary disease among ad...             %
# 4  Chronic obstructive pulmonary disease among ad...             %
#
#              DataValueType  DataValue  LowConfidenceLimit  \
# 0         Crude Prevalence        4.5                 3.2
# 1         Crude Prevalence        3.9                 3.3
# 2         Crude Prevalence        7.0                 5.7
# 3         Crude Prevalence       10.0                 8.7
# 4  Age-adjusted Prevalence        5.3                 4.3
#
#    HighConfidenceLimit StratificationCategory1      Stratification1  \
# 0                  6.2                     Age            Age 18-44
# 1                  4.6                     Sex                 Male
# 2                  8.7          Race/Ethnicity  Black, non-Hispanic
# 3                 11.5                     Age             Age >=65
# 4                  6.5                     Sex                 Male
#
#                                       Geolocation QuestionID  \
# 0    POINT (-92.27449074299966 34.74865012400045)     COPD01
# 1   POINT (-120.99999953799971 37.63864012300047)     COPD01
# 2    POINT (-86.63186076199969 32.84057112200048)     COPD01
# 3   POINT (-120.99999953799971 37.63864012300047)     COPD01
# 4  POINT (-111.76381127699972 34.865970280000454)     COPD01
#
#   StratificationCategoryID1 StratificationID1
# 0                       AGE           AGE1844
# 1                       SEX              SEXM
# 2                      RACE               BLK
# 3                       AGE            AGE65P
# 4                       SEX              SEXM

# %%
#Group Data by data value type 
def group_by_data_value_type(df):
    grouped_data = df.groupby('DataValueType')
    
    # Optionally: Print summary of the groups
    print("Group Summary:")
    for data_value_type, group in grouped_data:
        print(f"\nDataValueType: {data_value_type}")
        print(group.head())  # Print the first few rows for each group
    
    # Return the grouped data if needed for further processing
    return grouped_data

print(group_by_data_value_type(df))
# Out:
# Group Summary:
#
# DataValueType: Age-adjusted Prevalence
#     YearStart  YearEnd LocationDesc DataSource  \
# 4        2019     2019      Arizona      BRFSS
# 6        2019     2019   California      BRFSS
# 14       2019     2019      Alabama      BRFSS
# 15       2019     2019   California      BRFSS
# 17       2019     2019   California      BRFSS
#
#                                     Topic  \
# 4   Chronic Obstructive Pulmonary Disease
# 6   Chronic Obstructive Pulmonary Disease
# 14  Chronic Obstructive Pulmonary Disease
# 15  Chronic Obstructive Pulmonary Disease
# 17  Chronic Obstructive Pulmonary Disease
#
#                                              Question DataValueUnit  \
# 4   Chronic obstructive pulmonary disease among ad...             %
# 6   Chronic obstructive pulmonary disease among ad...             %
# 14  Chronic obstructive pulmonary disease among ad...             %
# 15  Chronic obstructive pulmonary disease among ad...             %
# 17  Chronic obstructive pulmonary disease among ad...             %
#
#               DataValueType  DataValue  LowConfidenceLimit  \
# 4   Age-adjusted Prevalence        5.3                 4.3
# 6   Age-adjusted Prevalence        3.0                 1.7
# 14  Age-adjusted Prevalence        8.2                 7.0
# 15  Age-adjusted Prevalence        4.2                 3.8
# 17  Age-adjusted Prevalence        3.6                 2.9
#
#     HighConfidenceLimit StratificationCategory1      Stratification1  \
# 4                   6.5                     Sex                 Male
# 6                   5.3          Race/Ethnicity  Asian, non-Hispanic
# 14                  9.5                     Sex                 Male
# 15                  4.7                 Overall              Overall
# 17                  4.5          Race/Ethnicity             Hispanic
#
#                                        Geolocation QuestionID  \
# 4   POINT (-111.76381127699972 34.865970280000454)     COPD01
# 6    POINT (-120.99999953799971 37.63864012300047)     COPD01
# 14    POINT (-86.63186076199969 32.84057112200048)     COPD01
# 15   POINT (-120.99999953799971 37.63864012300047)     COPD01
# 17   POINT (-120.99999953799971 37.63864012300047)     COPD01
#
#    StratificationCategoryID1 StratificationID1
# 4                        SEX              SEXM
# 6                       RACE               ASN
# 14                       SEX              SEXM
# 15                   OVERALL               OVR
# 17                      RACE               HIS
#
# DataValueType: Crude Prevalence
#    YearStart  YearEnd LocationDesc DataSource  \
# 0       2019     2019     Arkansas      BRFSS
# 1       2019     2019   California      BRFSS
# 2       2019     2019      Alabama      BRFSS
# 3       2019     2019   California      BRFSS
# 5       2019     2019   California      BRFSS
#
#                                    Topic  \
# 0  Chronic Obstructive Pulmonary Disease
# 1  Chronic Obstructive Pulmonary Disease
# 2  Chronic Obstructive Pulmonary Disease
# 3  Chronic Obstructive Pulmonary Disease
# 5  Chronic Obstructive Pulmonary Disease
#
#                                             Question DataValueUnit  \
# 0  Chronic obstructive pulmonary disease among ad...             %
# 1  Chronic obstructive pulmonary disease among ad...             %
# 2  Chronic obstructive pulmonary disease among ad...             %
# 3  Chronic obstructive pulmonary disease among ad...             %
# 5  Chronic obstructive pulmonary disease among ad...             %
#
#       DataValueType  DataValue  LowConfidenceLimit  HighConfidenceLimit  \
# 0  Crude Prevalence        4.5                 3.2                  6.2
# 1  Crude Prevalence        3.9                 3.3                  4.6
# 2  Crude Prevalence        7.0                 5.7                  8.7
# 3  Crude Prevalence       10.0                 8.7                 11.5
# 5  Crude Prevalence        3.7                 2.5                  5.6
#
#   StratificationCategory1      Stratification1  \
# 0                     Age            Age 18-44
# 1                     Sex                 Male
# 2          Race/Ethnicity  Black, non-Hispanic
# 3                     Age             Age >=65
# 5          Race/Ethnicity  Black, non-Hispanic
#
#                                      Geolocation QuestionID  \
# 0   POINT (-92.27449074299966 34.74865012400045)     COPD01
# 1  POINT (-120.99999953799971 37.63864012300047)     COPD01
# 2   POINT (-86.63186076199969 32.84057112200048)     COPD01
# 3  POINT (-120.99999953799971 37.63864012300047)     COPD01
# 5  POINT (-120.99999953799971 37.63864012300047)     COPD01
#
#   StratificationCategoryID1 StratificationID1
# 0                       AGE           AGE1844
# 1                       SEX              SEXM
# 2                      RACE               BLK
# 3                       AGE            AGE65P
# 5                      RACE               BLK
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f56052780a0>
